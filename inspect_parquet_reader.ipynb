# %%
import os
import pandas as pd
import numpy as np

from utils.parquet_reader import *

# %%
from pathlib import Path

# sys.path[0] is the directory of the script that was initially run
PROJECT_ROOT = Path.cwd()
DATA_BASE_PATH = os.path.join(PROJECT_ROOT, "project_data")
PRICE_DATA_PATH = os.path.join(DATA_BASE_PATH, "price_data")
SENTIMENT_DATA_PATH = os.path.join(DATA_BASE_PATH, "sentiment_data")

# %%
inspect_all_parquet_in_directory(PRICE_DATA_PATH)
# Out:
# ==================== Inspecting Parquet files in: c:\Users\ag\alvaro\git\Stocks\stocks_workspace\project_data\price_data ====================
#
# --- Inspecting: c:\Users\ag\alvaro\git\Stocks\stocks_workspace\project_data\price_data\AAPL.parquet ---
# Shape: (3876, 5)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3876 entries, 2010-01-04 to 2025-05-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    3876 non-null   float64
#  1   high    3876 non-null   float64
#  2   low     3876 non-null   float64
#  3   close   3876 non-null   float64
#  4   volume  3876 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 181.7 KB
#
# Head:
#                 open      high       low     close     volume
# date
# 2010-01-04  6.414464  6.446622  6.382907  6.431896  493729600
# 2010-01-05  6.449629  6.479382  6.409055  6.443017  601904800
# 2010-01-06  6.443016  6.468562  6.333919  6.340531  552160000
# 2010-01-07  6.363975  6.371489  6.282828  6.328811  477131200
# 2010-01-08  6.320394  6.371487  6.283128  6.370885  447610800
#
# Tail:
#                   open        high         low       close    volume
# date
# 2025-05-23  193.669998  197.699997  193.460007  195.270004  78432900
# 2025-05-27  198.300003  200.740005  197.429993  200.210007  56288500
# 2025-05-28  200.589996  202.729996  199.899994  200.419998  45339700
# 2025-05-29  203.580002  203.809998  198.509995  199.949997  51396800
# 2025-05-30  199.369995  201.960007  196.779999  200.850006  70753100
#
# Index Details:
#   Index Name: date
#   Index Dtype: datetime64[ns]
#   Is Monotonic Increasing: True
#   Min Date: 2010-01-04 00:00:00
#   Max Date: 2025-05-30 00:00:00
#
# Missing Values per Column:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# --------------------------------------------------
#
# --- Inspecting: c:\Users\ag\alvaro\git\Stocks\stocks_workspace\project_data\price_data\AIR.PA.parquet ---
# Shape: (3941, 5)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3941 entries, 2010-01-04 to 2025-05-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    3941 non-null   float64
#  1   high    3941 non-null   float64
#  2   low     3941 non-null   float64
#  3   close   3941 non-null   float64
#  4   volume  3941 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 184.7 KB
#
# Head:
#                  open       high        low      close   volume
# date
# 2010-01-04  11.184293  11.224237  11.104405  11.176304  2496013
# 2010-01-05  11.088427  11.204264  10.948624  11.140354  2700340
# 2010-01-06  11.152338  11.256192  11.124377  11.240214  3993940
# 2010-01-07  11.112395  11.395997  11.072451  11.352058  4633114
# 2010-01-08  11.435941  11.567756  11.348065  11.463902  2289556
#
# Tail:
#                   open        high         low       close   volume
# date
# 2025-05-26  160.320007  161.440002  160.100006  160.220001   556583
# 2025-05-27  160.460007  163.259995  160.460007  162.199997   723948
# 2025-05-28  162.500000  165.759995  161.860001  162.339996  1337656
# 2025-05-29  164.919998  165.399994  162.479996  162.559998   611176
# 2025-05-30  162.539993  163.960007  162.080002  162.080002  1136818
#
# Index Details:
#   Index Name: date
#   Index Dtype: datetime64[ns]
#   Is Monotonic Increasing: True
#   Min Date: 2010-01-04 00:00:00
#   Max Date: 2025-05-30 00:00:00
#
# Missing Values per Column:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# --------------------------------------------------
#
# --- Inspecting: c:\Users\ag\alvaro\git\Stocks\stocks_workspace\project_data\price_data\MSFT.parquet ---
# Shape: (3876, 5)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3876 entries, 2010-01-04 to 2025-05-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    3876 non-null   float64
#  1   high    3876 non-null   float64
#  2   low     3876 non-null   float64
#  3   close   3876 non-null   float64
#  4   volume  3876 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 181.7 KB
#
# Head:
#                  open       high        low      close    volume
# date
# 2010-01-04  22.963952  23.323936  22.941453  23.211441  38409100
# 2010-01-05  23.136445  23.323937  22.978952  23.218941  49749600
# 2010-01-06  23.158940  23.308934  22.888953  23.076445  58182400
# 2010-01-07  22.971439  23.023938  22.641456  22.836447  50559700
# 2010-01-08  22.708967  23.158946  22.678968  22.993954  51197400
#
# Tail:
#                   open        high         low       close    volume
# date
# 2025-05-23  449.980011  453.690002  448.910004  450.179993  16883500
# 2025-05-27  456.480011  460.950012  456.119995  460.690002  20974300
# 2025-05-28  461.220001  462.519989  456.929993  457.359985  17086300
# 2025-05-29  461.549988  461.720001  455.309998  458.679993  13974800
# 2025-05-30  459.720001  461.679993  455.540009  460.359985  34760500
#
# Index Details:
#   Index Name: date
#   Index Dtype: datetime64[ns]
#   Is Monotonic Increasing: True
#   Min Date: 2010-01-04 00:00:00
#   Max Date: 2025-05-30 00:00:00
#
# Missing Values per Column:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# --------------------------------------------------
#
# --- Inspecting: c:\Users\ag\alvaro\git\Stocks\stocks_workspace\project_data\price_data\NVDA.parquet ---
# Shape: (3876, 5)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3876 entries, 2010-01-04 to 2025-05-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    3876 non-null   float64
#  1   high    3876 non-null   float64
#  2   low     3876 non-null   float64
#  3   close   3876 non-null   float64
#  4   volume  3876 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 181.7 KB
#
# Head:
#                 open      high       low     close     volume
# date
# 2010-01-04  0.424342  0.426864  0.415172  0.423884  800204000
# 2010-01-05  0.422279  0.434659  0.422279  0.430073  728648000
# 2010-01-06  0.429844  0.433741  0.425718  0.432824  649168000
# 2010-01-07  0.430532  0.432366  0.421133  0.424342  547792000
# 2010-01-08  0.420903  0.428239  0.418382  0.425259  478168000
#
# Tail:
#                   open        high         low       close     volume
# date
# 2025-05-23  130.000000  132.679993  129.160004  131.289993  198821300
# 2025-05-27  134.149994  135.660004  133.309998  135.500000  192953600
# 2025-05-28  136.029999  137.250000  134.789993  134.809998  304021100
# 2025-05-29  142.250000  143.490005  137.910004  139.190002  369241900
# 2025-05-30  138.720001  139.619995  132.919998  135.130005  332443400
#
# Index Details:
#   Index Name: date
#   Index Dtype: datetime64[ns]
#   Is Monotonic Increasing: True
#   Min Date: 2010-01-04 00:00:00
#   Max Date: 2025-05-30 00:00:00
#
# Missing Values per Column:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# --------------------------------------------------
#
# --- Inspecting: c:\Users\ag\alvaro\git\Stocks\stocks_workspace\project_data\price_data\PHIA.AS.parquet ---
# Shape: (3944, 5)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3944 entries, 2010-01-04 to 2025-05-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    3944 non-null   float64
#  1   high    3944 non-null   float64
#  2   low     3944 non-null   float64
#  3   close   3944 non-null   float64
#  4   volume  3944 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 184.9 KB
#
# Head:
#                  open       high        low      close   volume
# date
# 2010-01-04  11.929869  12.254452  11.855841  12.240216  4579593
# 2010-01-05  12.186116  12.348408  12.129171  12.214588  9998792
# 2010-01-06  12.151949  12.203199  11.941255  12.026672  4956226
# 2010-01-07  12.020978  12.072228  11.833061  11.958339  5041171
# 2010-01-08  12.038063  12.129174  11.838758  11.975425  4634241
#
# Tail:
#                  open       high        low      close   volume
# date
# 2025-05-26  20.190001  20.480000  20.150000  20.420000  1256659
# 2025-05-27  20.379999  20.549999  20.350000  20.420000   969231
# 2025-05-28  20.360001  20.450001  20.290001  20.330000  1631854
# 2025-05-29  20.500000  20.750000  20.280001  20.280001  2028012
# 2025-05-30  20.180000  20.309999  20.090000  20.250000  4761327
#
# Index Details:
#   Index Name: date
#   Index Dtype: datetime64[ns]
#   Is Monotonic Increasing: True
#   Min Date: 2010-01-04 00:00:00
#   Max Date: 2025-05-30 00:00:00
#
# Missing Values per Column:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# --------------------------------------------------
#
# --- Inspecting: c:\Users\ag\alvaro\git\Stocks\stocks_workspace\project_data\price_data\TSLA.parquet ---
# Shape: (3754, 5)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-06-29 to 2025-05-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    3754 non-null   float64
#  1   high    3754 non-null   float64
#  2   low     3754 non-null   float64
#  3   close   3754 non-null   float64
#  4   volume  3754 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 176.0 KB
#
# Head:
#                 open      high       low     close     volume
# date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000  103003500
#
# Tail:
#                   open        high         low       close     volume
# date
# 2025-05-23  337.920013  343.179993  333.209991  339.339996   84654800
# 2025-05-27  347.350006  363.790009  347.320007  362.890015  120146400
# 2025-05-28  364.839996  365.000000  355.910004  356.899994   91404300
# 2025-05-29  365.290009  367.709991  356.000000  358.429993   88545700
# 2025-05-30  355.519989  363.679993  345.290009  346.459991  123097900
#
# Index Details:
#   Index Name: date
#   Index Dtype: datetime64[ns]
#   Is Monotonic Increasing: True
#   Min Date: 2010-06-29 00:00:00
#   Max Date: 2025-05-30 00:00:00
#
# Missing Values per Column:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# --------------------------------------------------

# %%
ticker_to_check = "TSLA"
price_file = os.path.join(PRICE_DATA_PATH, f"{ticker_to_check}.parquet")
sentiment_file = os.path.join(SENTIMENT_DATA_PATH, f"{ticker_to_check}_sentiment.parquet")
inspect_parquet_file(price_file)
inspect_parquet_file(sentiment_file)
# Out:
# --- Inspecting: c:\Users\ag\alvaro\git\Stocks\stocks_workspace\project_data\price_data\TSLA.parquet ---
# Shape: (3754, 5)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-06-29 to 2025-05-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    3754 non-null   float64
#  1   high    3754 non-null   float64
#  2   low     3754 non-null   float64
#  3   close   3754 non-null   float64
#  4   volume  3754 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 176.0 KB
#
# Head:
#                 open      high       low     close     volume
# date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000  103003500
#
# Tail:
#                   open        high         low       close     volume
# date
# 2025-05-23  337.920013  343.179993  333.209991  339.339996   84654800
# 2025-05-27  347.350006  363.790009  347.320007  362.890015  120146400
# 2025-05-28  364.839996  365.000000  355.910004  356.899994   91404300
# 2025-05-29  365.290009  367.709991  356.000000  358.429993   88545700
# 2025-05-30  355.519989  363.679993  345.290009  346.459991  123097900
#
# Index Details:
#   Index Name: date
#   Index Dtype: datetime64[ns]
#   Is Monotonic Increasing: True
#   Min Date: 2010-06-29 00:00:00
#   Max Date: 2025-05-30 00:00:00
#
# Missing Values per Column:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# File not found: c:\Users\ag\alvaro\git\Stocks\stocks_workspace\project_data\sentiment_data\TSLA_sentiment.parquet
